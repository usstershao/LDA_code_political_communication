# %%
# Downloaded from doug.specht.co.uk/twitter-research

# %%
import sys
import json
import re
import numpy as np
from datetime import datetime
import pandas as pd  

tweetfile = 'Twitterset1.csv'

tweets = pd.read_csv(tweetfile)

# %%
tweets.columns
# Out:
# Index(['id_str', 'from_user', 'text', 'created_at', 'time', 'geo_coordinates',
#        'user_lang', 'in_reply_to_user_id_str', 'in_reply_to_screen_name',
#        'from_user_id_str', 'in_reply_to_status_id_str', 'source',
#        'profile_image_url', 'user_followers_count', 'user_friends_count',
#        'user_location', 'status_url', 'entities_str'],
#       dtype='object')

# %%
tweets.head()
# Out:
#                 id_str        from_user  \
# 0  1246006923113238528     AnaAlvarezTw
# 1  1245915059886239749   SemillaRebelde
# 2  1245914985479495680      BasuraCero_
# 3  1245914912666390529  DesdeConciencia
# 4  1245914792625238018  caperucita_soja
#
#                                                 text  \
# 0  @MendozaFracking @arcionimariano @ecologicosmz...
# 1  RT @ConSol_ONG: He publicado un episodio en #i...
# 2  RT @ConSol_ONG: He publicado un episodio en #i...
# 3  RT @ConSol_ONG: He publicado un episodio en #i...
# 4  RT @ConSol_ONG: He publicado un episodio en #i...
#
#                        created_at                 time  geo_coordinates  \
# 0  Fri Apr 03 09:29:34 +0000 2020  03/04/2020 10:29:34              NaN
# 1  Fri Apr 03 03:24:32 +0000 2020  03/04/2020 04:24:32              NaN
# 2  Fri Apr 03 03:24:15 +0000 2020  03/04/2020 04:24:15              NaN
# 3  Fri Apr 03 03:23:57 +0000 2020  03/04/2020 04:23:57              NaN
# 4  Fri Apr 03 03:23:29 +0000 2020  03/04/2020 04:23:29              NaN
#
#    user_lang  in_reply_to_user_id_str in_reply_to_screen_name  \
# 0        NaN             1.229415e+18         MendozaFracking
# 1        NaN                      NaN                     NaN
# 2        NaN                      NaN                     NaN
# 3        NaN                      NaN                     NaN
# 4        NaN                      NaN                     NaN
#
#       from_user_id_str  in_reply_to_status_id_str  \
# 0   987885562710413318               1.244701e+18
# 1   714995200616239104                        NaN
# 2  1037858560460435462                        NaN
# 3   930249293671403520                        NaN
# 4   904801618805317633                        NaN
#
#                                               source  \
# 0  <a href="http://twitter.com/download/android" ...
# 1  <a href="http://twitter.com/download/android" ...
# 2  <a href="http://twitter.com/download/android" ...
# 3  <a href="http://twitter.com/download/android" ...
# 4  <a href="http://twitter.com/download/android" ...
#
#                                    profile_image_url  user_followers_count  \
# 0  http://pbs.twimg.com/profile_images/1163199744...                  58.0
# 1  http://pbs.twimg.com/profile_images/9253394718...                 206.0
# 2  http://pbs.twimg.com/profile_images/1050531446...                  34.0
# 3  http://pbs.twimg.com/profile_images/1241535054...                  84.0
# 4  http://pbs.twimg.com/profile_images/9253403188...                  91.0
#
#    user_friends_count                user_location  \
# 0                 161                          NaN
# 1                 182  Capilla del Monte, Córdoba.
# 2                 126   Capilla del Monte, Córdoba
# 3                 175                          NaN
# 4                 467  Capilla del Monte, Córdoba.
#
#                                           status_url  \
# 0  http://twitter.com/AnaAlvarezTw/statuses/12460...
# 1  http://twitter.com/SemillaRebelde/statuses/124...
# 2  http://twitter.com/BasuraCero_/statuses/124591...
# 3  http://twitter.com/DesdeConciencia/statuses/12...
# 4  http://twitter.com/caperucita_soja/statuses/12...
#
#                                         entities_str
# 0  {"hashtags":[],"symbols":[],"user_mentions":[{...
# 1  {"hashtags":[{"text":"ivoox","indices":[44,50]...
# 2  {"hashtags":[{"text":"ivoox","indices":[44,50]...
# 3  {"hashtags":[{"text":"ivoox","indices":[44,50]...
# 4  {"hashtags":[{"text":"ivoox","indices":[44,50]...

# %%
# 3. Export edges from Replies

replies = tweets[tweets['in_reply_to_screen_name'].notnull()]

edges = replies[['from_user', 'in_reply_to_screen_name','created_at']]
edges.columns = ['Source', 'Target', 'Strength']

# %%
strengthLevel = 3  # Network connection strength level: the number of times in total each of the tweeters responded to or mentioned the other.
                   # If you have 1 as the level, then all tweeters who mentioned or replied to another at least once will be displayed. But if you have 5, only those who have mentioned or responded to a particular tweeter at least 5 times will be displayed, which means that only the strongest bonds are shown.

edges2 = edges.groupby(['Source','Target'])['Strength'].count()
edges2 = edges2.reset_index()
edges2 = edges2[edges2['Strength'] >= strengthLevel]

# %%
# Export nodes from the edges and add node attributes for both Sources and Targets.

users = tweets[['from_user','user_followers_count', 'user_friends_count']]
users = users.sort_values(['from_user','user_followers_count'], ascending=[True, False])
users = users.drop_duplicates(['from_user'], keep='first') 

ids = edges2['Source'].append(edges2['Target']).to_frame()
ids['Label'] = ids
ids.columns = ['from_user', 'Label']
ids = ids.drop_duplicates(['from_user'], keep='first') 
nodes = pd.merge(ids, users, on='from_user', how='left')

# %%
print(nodes.shape)
print(edges2.shape)
# Out:
# (24, 4)
# (29, 3)

# %%
# change column names for Kumu import (Run this when using Kumu)
edges2.columns = ['Source','Target','Strength']
nodes.columns = ['Id', 'Label', 'user_followers_count', 'user_friends_count']

# %%
# Print nodes to check
nodes.head(3)
# Out:
#             Id        Label  user_followers_count  user_friends_count
# 0    AntMalen2    AntMalen2                  27.0                  65
# 1   BrunoMBrac   BrunoMBrac                 345.0                2037
# 2  ElbaLedesma  ElbaLedesma                 307.0                 997

# %%
# Print edges to check
edges2.head(3)
# Out:
#         Source      Target  Strength
# 7    AntMalen2   AntMalen2         3
# 12  BrunoMBrac  BrunoMBrac        10
# 13  BrunoMBrac  Inm93Munoz         4

# %%
# Export nodes and edges to csv files
nodes.to_csv('nodes.csv', encoding='utf-8', index=False)
edges2.to_csv('edges.csv', encoding='utf-8', index=False)
